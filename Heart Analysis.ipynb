# %% [markdown]
# ## Importing library

# %%
import pandas as pd

# %% [markdown]
# ## Reading data

# %%
heart= pd.read_csv("Heart.csv")

# %% [markdown]
# ## Info about data

# %%
heart.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
heart.shape
# Out:
# (303, 15)

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %% [markdown]
# ## Cleaning Data

# %%
# replacing all null values of the column Cal with the mean value
moy_Ca=heart["Ca"].mean()
heart["Ca"].fillna(moy_Ca,inplace=True)

# %%
# replacing all null values of the column Thal with the fréquent value
freq_Thal=heart["Thal"].mode()[0]
heart.Thal.fillna(freq_Thal,inplace=True)

# %%
# Here we make sure we fill all the null values
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          303 non-null    float64
#  13  Thal        303 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %%
# we have the first column with the label 0 that is'nt pertinent, we will drop it.
heart.drop(["Unnamed: 0"],axis=1, inplace=True)

# %%
heart.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1       typical     145   233    1        2    150      0      2.3
# 1   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 2   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 3   37    1    nonanginal     130   250    0        0    187      0      3.5
# 4   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 0      3  0.0       fixed   No
# 1      2  3.0      normal  Yes
# 2      2  2.0  reversable  Yes
# 3      3  0.0      normal   No
# 4      1  0.0      normal   No

# %%
# Now, we will make sure that we don't have duplicated values
heart.drop_duplicates(inplace=True)

# %%
heart.shape
# Out:
# (303, 14)

# %% [markdown]
# ## Visualise our dataset

# %%
# we will see first the desciption of the our dataset first
heart.describe(include="all")
# Out:
#                Age         Sex     ChestPain      RestBP        Chol  \
# count   303.000000  303.000000           303  303.000000  303.000000
# unique         NaN         NaN             4         NaN         NaN
# top            NaN         NaN  asymptomatic         NaN         NaN
# freq           NaN         NaN           144         NaN         NaN
# mean     54.438944    0.679868           NaN  131.689769  246.693069
# std       9.038662    0.467299           NaN   17.599748   51.776918
# min      29.000000    0.000000           NaN   94.000000  126.000000
# 25%      48.000000    0.000000           NaN  120.000000  211.000000
# 50%      56.000000    1.000000           NaN  130.000000  241.000000
# 75%      61.000000    1.000000           NaN  140.000000  275.000000
# max      77.000000    1.000000           NaN  200.000000  564.000000
#
#                Fbs     RestECG       MaxHR       ExAng     Oldpeak  \
# count   303.000000  303.000000  303.000000  303.000000  303.000000
# ...

# %%
# corrolations between columns
heart_encoded=pd.get_dummies(heart)
heart_encoded.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_49974_row0_col0, #T_49974_row1_col1, #T_49974_row2_col2, #T_49974_row3_col3, #T_49974_row4_col4, #T_49974_row5_col5, #T_49974_row6_col6, #T_49974_row7_col7, #T_49974_row8_col8, #T_49974_row9_col9, #T_49974_row10_col10, #T_49974_row11_col11, #T_49974_row12_col12, #T_49974_row13_col13, #T_49974_row14_col14, #T_49974_row15_col15, #T_49974_row16_col16, #T_49974_row17_col17, #T_49974_row18_col18, #T_49974_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_49974_row0_col1, #T_49974_row7_col12, #T_49974_row12_col8, #T_49974_row13_col10, #T_49974_row14_col13, #T_49974_row17_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_49974_row0_col2, #T_49974_row1_col10, #T_49974_row5_col8, #T_49974_row13_col19 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_49974_row0_col3, #T_49974_row0_col12, #T_49974_row2_col12, #T_49974_row11_col1, #T_49974_row12_col19 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# ...

# %%
heart.plot(kind="scatter",x="MaxHR",y="Age")
# Out:
# <AxesSubplot:xlabel='MaxHR', ylabel='Age'>

# %%
# We can see here the sex frequency
heart[heart["AHD"] == 'Yes'].Sex.hist()
# Out:
# <AxesSubplot:>

# %%
# We can see here the age frequency
heart[heart["AHD"] == 'Yes'].Age.hist()
# Out:
# <AxesSubplot:>

# %%
heart.plot(kind="scatter",y="Chol",x="Age")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Chol'>

# %%
heart.ChestPain.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
heart[heart["AHD"] == 'Yes'].Age.value_counts().head()
# Out:
# 58    12
# 57    10
# 60     9
# 59     9
# 62     7
# Name: Age, dtype: int64

# %%
heart[heart["AHD"] == 'Yes'].Age.value_counts().tail()
# Out:
# 77    1
# 41    1
# 69    1
# 38    1
# 42    1
# Name: Age, dtype: int64
